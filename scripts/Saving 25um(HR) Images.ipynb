# %%
import utility as ut

# %% [markdown]
# # Z-axis Images

# %% [markdown]
# ### F1 160

# %%
datapath_hr= '../OneDrive_1_11-10-2021/AD_P522R_F1_160/MRI_25um/mag_sos_wn.nii'
data_hr = ut.load_data_nii(datapath_hr)

main_path= '../images/25um/z_axis/f1_160/'
sub_path_2='hr_f1_160_2'
sub_path_4 ='hr_f1_160_4'
sub_path_8 ='hr_f1_160_8'
hr_path ='hr_f1_160'

# saving lr cropped and padded by fac 2
x,y,z = data_hr.shape
for i in range(z):
    img = ut.crop_pad_image_kspace(data_hr[:,:,i],pad=True,factor=2)
    img = ut.normalize_image(img)
    name= sub_path_2 + '_' + str(i)
    ut.save_img_using_pil_lib(img,name,main_path+sub_path_2+'/')
    
#saving lr cropped and padded by fac 4
x,y,z = data_hr.shape
for i in range(z):
    img = ut.crop_pad_image_kspace(data_hr[:,:,i],pad=True,factor=4)
    img = ut.normalize_image(img)
    name= sub_path_4 + '_' + str(i)
    ut.save_img_using_pil_lib(img,name,main_path+sub_path_4+'/')


# saving lr cropped and padded by fac 8
x,y,z = data_hr.shape
for i in range(z):
    img = ut.crop_pad_image_kspace(data_hr[:,:,i],pad=True,factor=8)
    img = ut.normalize_image(img)
    name= sub_path_8 + '_'+str(i)
    ut.save_img_using_pil_lib(img,name,main_path+sub_path_8+'/')
    
    
# saving hr images
x,y,z = data_hr.shape
for i in range(z):
    name= hr_path+ '_'+str(i)
    img = ut.normalize_image(data_hr[:,:,i])
    ut.save_img_using_pil_lib(img,name,main_path + hr_path+'/')

# %% [markdown]
# ## F2 145

# %%
datapath_hr= '../OneDrive_1_11-10-2021/AD_P522R_F2_145/MRI_25um/mag_sos_wn.nii'
data_hr = ut.load_data_nii(datapath_hr)

main_path= '../images/25um/z_axis/f2_145/'
sub_path_2='hr_f2_145_2'
sub_path_4 ='hr_f2_145_4'
sub_path_8 ='hr_f2_145_8'
hr_path ='hr_f2_145'

# saving lr cropped and padded by fac 2
x,y,z = data_hr.shape
for i in range(z):
    img = ut.crop_pad_image_kspace(data_hr[:,:,i],pad=True,factor=2)
    img = ut.normalize_image(img)
    name= sub_path_2 + '_' + str(i)
    ut.save_img_using_pil_lib(img,name,main_path+sub_path_2+'/')
    
    
# saving lr cropped and padded by fac 4
x,y,z = data_hr.shape
for i in range(z):
    img = ut.crop_pad_image_kspace(data_hr[:,:,i],pad=True,factor=4)
    img = ut.normalize_image(img)
    name= sub_path_4 + '_' + str(i)
    ut.save_img_using_pil_lib(img,name,main_path+sub_path_4+'/')


# saving lr cropped and padded by fac 8
x,y,z = data_hr.shape
for i in range(z):
    img = ut.crop_pad_image_kspace(data_hr[:,:,i],pad=True,factor=8)
    img = ut.normalize_image(img)
    name= sub_path_8 + '_'+str(i)
    ut.save_img_using_pil_lib(img,name,main_path+sub_path_8+'/')
    
    
# saving hr images
x,y,z = data_hr.shape
for i in range(z):
    name= hr_path+ '_'+str(i)
    img = ut.normalize_image(data_hr[:,:,i])
    ut.save_img_using_pil_lib(img,name,main_path + hr_path+'/')

# %% [markdown]
# ### F3 147

# %%
# datapath_hr= '../OneDrive_1_11-10-2021/AD_P522R_F3_147/MRI_25um/mag_sos_wn.nii'
# data_hr = ut.load_data_nii(datapath_hr)

# main_path= '../images/f3_147/'
# sub_path_2='lr_f3_147_2'
# sub_path_8 ='lr_f3_147_8'
# hr_path ='hr_f3_147'

# # saving lr cropped by fac 2
# x,y,z = data_hr.shape
# for i in range(z):
#     img = ut.crop_pad_image_kspace(data_hr[:,:,i],pad=True,factor=2)
#     img = ut.normalize_image(img)
#     name= sub_path_2 + '_' + str(i)
#     ut.save_img_using_pil_lib(img,name,main_path+sub_path_2+'/')


# # saving lr cropped by fac 8
# x,y,z = data_hr.shape
# for i in range(z):
#     img = ut.crop_pad_image_kspace(data_hr[:,:,i],pad=True,factor=8)
#     img = ut.normalize_image(img)
#     name= sub_path_8 + '_'+str(i)
#     ut.save_img_using_pil_lib(img,name,main_path+sub_path_8+'/')
    
    
# # saving hr images
# x,y,z = data_hr.shape
# for i in range(z):
#     name= hr_path+ '_'+str(i)
#     img = ut.normalize_image(data_hr[:,:,i])
#     ut.save_img_using_pil_lib(img,name,main_path + hr_path+'/')

# %% [markdown]
# ## F4 149

# %%
datapath_hr= '../OneDrive_1_11-10-2021/AD_P522R_F4_149/MRI_25um/mag_sos_wn.nii'
data_hr = ut.load_data_nii(datapath_hr)

main_path= '../images/25um/z_axis/f4_149/'
sub_path_2='hr_f4_149_2'
sub_path_4='hr_f4_149_4'
sub_path_8 ='hr_f4_149_8'
hr_path ='hr_f4_149'

# saving lr cropped  and padded by fac 2
x,y,z = data_hr.shape
for i in range(z):
    img = ut.crop_pad_image_kspace(data_hr[:,:,i],pad=True,factor=2)
    img = ut.normalize_image(img)
    name= sub_path_2 + '_' + str(i)
    ut.save_img_using_pil_lib(img,name,main_path+sub_path_2+'/')
    
# saving lr cropped  and padded by fac 4
x,y,z = data_hr.shape
for i in range(z):
    img = ut.crop_pad_image_kspace(data_hr[:,:,i],pad=True,factor=4)
    img = ut.normalize_image(img)
    name= sub_path_4 + '_' + str(i)
    ut.save_img_using_pil_lib(img,name,main_path+sub_path_4+'/')


# # saving lr cropped and padded by fac 8
x,y,z = data_hr.shape
for i in range(z):
    img = ut.crop_pad_image_kspace(data_hr[:,:,i],pad=True,factor=8)
    img = ut.normalize_image(img)
    name= sub_path_8 + '_'+str(i)
    ut.save_img_using_pil_lib(img,name,main_path+sub_path_8+'/')
    
    
# # saving hr images
x,y,z = data_hr.shape
for i in range(z):
    name= hr_path+ '_'+str(i)
    img = ut.normalize_image(data_hr[:,:,i])
    ut.save_img_using_pil_lib(img,name,main_path + hr_path+'/')

# %% [markdown]
# ## F5 153

# %%
datapath_hr= '../OneDrive_1_11-10-2021/AD_P522R_F5_153/MRI_25um/mag_sos_wn.nii'
data_hr = ut.load_data_nii(datapath_hr)

main_path= '../images/25um/z_axis/f5_153/'
sub_path_2 ='hr_f5_153_2'
sub_path_4='hr_f5_153_4'
sub_path_8 ='hr_f5_153_8'
hr_path ='hr_f5_153'

# saving lr cropped and padded by fac 2
x,y,z = data_hr.shape
for i in range(z):
    img = ut.crop_pad_image_kspace(data_hr[:,:,i],pad=True,factor=2)
    img = ut.normalize_image(img)
    name= sub_path_2 + '_' + str(i)
    ut.save_img_using_pil_lib(img,name,main_path+sub_path_2+'/')

# saving lr cropped and padded by fac 2
x,y,z = data_hr.shape
for i in range(z):
    img = ut.crop_pad_image_kspace(data_hr[:,:,i],pad=True,factor=4)
    img = ut.normalize_image(img)
    name= sub_path_4 + '_' + str(i)
    ut.save_img_using_pil_lib(img,name,main_path+sub_path_4+'/')


# saving lr cropped and padded by fac 8
x,y,z = data_hr.shape
for i in range(z):
    img = ut.crop_pad_image_kspace(data_hr[:,:,i],pad=True,factor=8)
    img = ut.normalize_image(img)
    name= sub_path_8 + '_'+str(i)
    ut.save_img_using_pil_lib(img,name,main_path+sub_path_8+'/')
    
    
# saving hr images
x,y,z = data_hr.shape
for i in range(z):
    name= hr_path+ '_'+str(i)
    img = ut.normalize_image(data_hr[:,:,i])
    ut.save_img_using_pil_lib(img,name,main_path + hr_path+'/')

# %% [markdown]
# # Yaxis Images

# %% [markdown]
# ## F1 160

# %%
datapath_hr= '../OneDrive_1_11-10-2021/AD_P522R_F1_160/MRI_25um/mag_sos_wn.nii'
data_hr = ut.load_data_nii(datapath_hr)

main_path= '../images/25um/y_axis/f1_160/'
sub_path_2='hr_f1_160_2'
sub_path_4 ='hr_f1_160_4'
sub_path_8 ='hr_f1_160_8'
hr_path ='hr_f1_160'

# saving lr cropped and padded by fac 2
x,y,z = data_hr.shape
for i in range(y):
    img = ut.crop_pad_image_kspace(data_hr[:,i,:],pad=True,factor=2)
    img = ut.normalize_image(img)
    name= sub_path_2 + '_' + str(i)
    ut.save_img_using_pil_lib(img,name,main_path+sub_path_2+'/')
    
#saving lr cropped and padded by fac 4
x,y,z = data_hr.shape
for i in range(y):
    img = ut.crop_pad_image_kspace(data_hr[:,i,:],pad=True,factor=4)
    img = ut.normalize_image(img)
    name= sub_path_4 + '_' + str(i)
    ut.save_img_using_pil_lib(img,name,main_path+sub_path_4+'/')


# saving lr cropped and padded by fac 8
x,y,z = data_hr.shape
for i in range(y):
    img = ut.crop_pad_image_kspace(data_hr[:,i,:],pad=True,factor=8)
    img = ut.normalize_image(img)
    name= sub_path_8 + '_'+str(i)
    ut.save_img_using_pil_lib(img,name,main_path+sub_path_8+'/')
    
    
# saving hr images
x,y,z = data_hr.shape
for i in range(y):
    name= hr_path+ '_'+str(i)
    img = ut.normalize_image(data_hr[:,i,:])
    ut.save_img_using_pil_lib(img,name,main_path + hr_path+'/')

# %% [markdown]
# ## F2 145

# %%
datapath_hr= '../OneDrive_1_11-10-2021/AD_P522R_F2_145/MRI_25um/mag_sos_wn.nii'
data_hr = ut.load_data_nii(datapath_hr)


main_path= '../images/25um/y_axis/f2_145/'
sub_path_2='hr_f2_145_2'
sub_path_4 ='hr_f2_145_4'
sub_path_8 ='hr_f2_145_8'
hr_path ='hr_f2_145'

# saving lr cropped and padded by fac 2
x,y,z = data_hr.shape
for i in range(y):
    img = ut.crop_pad_image_kspace(data_hr[:,i,:],pad=True,factor=2)
    img = ut.normalize_image(img)
    name= sub_path_2 + '_' + str(i)
    ut.save_img_using_pil_lib(img,name,main_path+sub_path_2+'/')
    
    
# saving lr cropped and padded by fac 4
x,y,z = data_hr.shape
for i in range(y):
    img = ut.crop_pad_image_kspace(data_hr[:,i,:],pad=True,factor=4)
    img = ut.normalize_image(img)
    name= sub_path_4 + '_' + str(i)
    ut.save_img_using_pil_lib(img,name,main_path+sub_path_4+'/')


# saving lr cropped and padded by fac 8
x,y,z = data_hr.shape
for i in range(y):
    img = ut.crop_pad_image_kspace(data_hr[:,i,:],pad=True,factor=8)
    img = ut.normalize_image(img)
    name= sub_path_8 + '_'+str(i)
    ut.save_img_using_pil_lib(img,name,main_path+sub_path_8+'/')
    
    
# saving hr images
x,y,z = data_hr.shape
for i in range(y):
    name= hr_path+ '_'+str(i)
    img = ut.normalize_image(data_hr[:,i,:])
    ut.save_img_using_pil_lib(img,name,main_path + hr_path+'/')

# %% [markdown]
# ## F4 149

# %%
datapath_hr= '../OneDrive_1_11-10-2021/AD_P522R_F4_149/MRI_25um/mag_sos_wn.nii'
data_hr = ut.load_data_nii(datapath_hr)

main_path= '../images/25um/y_axis/f4_149/'
sub_path_2='hr_f4_149_2'
sub_path_4='hr_f4_149_4'
sub_path_8 ='hr_f4_149_8'
hr_path ='hr_f4_149'

# saving lr cropped  and padded by fac 2
x,y,z = data_hr.shape
for i in range(y):
    img = ut.crop_pad_image_kspace(data_hr[:,i,:],pad=True,factor=2)
    img = ut.normalize_image(img)
    name= sub_path_2 + '_' + str(i)
    ut.save_img_using_pil_lib(img,name,main_path+sub_path_2+'/')
    
# saving lr cropped  and padded by fac 4
x,y,z = data_hr.shape
for i in range(y):
    img = ut.crop_pad_image_kspace(data_hr[:,i,:],pad=True,factor=4)
    img = ut.normalize_image(img)
    name= sub_path_4 + '_' + str(i)
    ut.save_img_using_pil_lib(img,name,main_path+sub_path_4+'/')


# # saving lr cropped and padded by fac 8
x,y,z = data_hr.shape
for i in range(y):
    img = ut.crop_pad_image_kspace(data_hr[:,i,:],pad=True,factor=8)
    img = ut.normalize_image(img)
    name= sub_path_8 + '_'+str(i)
    ut.save_img_using_pil_lib(img,name,main_path+sub_path_8+'/')
    
    
# # saving hr images
x,y,z = data_hr.shape
for i in range(y):
    name= hr_path+ '_'+str(i)
    img = ut.normalize_image(data_hr[:,i,:])
    ut.save_img_using_pil_lib(img,name,main_path + hr_path+'/')

# %% [markdown]
# ## F5 153

# %%
datapath_hr= '../OneDrive_1_11-10-2021/AD_P522R_F5_153/MRI_25um/mag_sos_wn.nii'
data_hr = ut.load_data_nii(datapath_hr)

main_path= '../images/25um/y_axis/f5_153/'
sub_path_2 ='hr_f5_153_2'
sub_path_4='hr_f5_153_4'
sub_path_8 ='hr_f5_153_8'
hr_path ='hr_f5_153'

# saving lr cropped and padded by fac 2
x,y,z = data_hr.shape
for i in range(y):
    img = ut.crop_pad_image_kspace(data_hr[:,i,:],pad=True,factor=2)
    img = ut.normalize_image(img)
    name= sub_path_2 + '_' + str(i)
    ut.save_img_using_pil_lib(img,name,main_path+sub_path_2+'/')

# saving lr cropped and padded by fac 2
x,y,z = data_hr.shape
for i in range(y):
    img = ut.crop_pad_image_kspace(data_hr[:,i,:],pad=True,factor=4)
    img = ut.normalize_image(img)
    name= sub_path_4 + '_' + str(i)
    ut.save_img_using_pil_lib(img,name,main_path+sub_path_4+'/')


# saving lr cropped and padded by fac 8
x,y,z = data_hr.shape
for i in range(y):
    img = ut.crop_pad_image_kspace(data_hr[:,i,:],pad=True,factor=8)
    img = ut.normalize_image(img)
    name= sub_path_8 + '_'+str(i)
    ut.save_img_using_pil_lib(img,name,main_path+sub_path_8+'/')
    
    
# saving hr images
x,y,z = data_hr.shape
for i in range(y):
    name= hr_path+ '_'+str(i)
    img = ut.normalize_image(data_hr[:,i,:])
    ut.save_img_using_pil_lib(img,name,main_path + hr_path+'/')

# %% [markdown]
# ## X axis Images

# %% [markdown]
# ## F1 160

# %%
datapath_hr= '../OneDrive_1_11-10-2021/AD_P522R_F1_160/MRI_25um/mag_sos_wn.nii'
data_hr = ut.load_data_nii(datapath_hr)


main_path= '../images/25um/x_axis/f1_160/'
sub_path_2='hr_f1_160_2'
sub_path_4 ='hr_f1_160_4'
sub_path_8 ='hr_f1_160_8'
hr_path ='hr_f1_160'

# saving lr cropped and padded by fac 2
x,y,z = data_hr.shape
for i in range(x):
    img = ut.crop_pad_image_kspace(data_hr[i,:,:],pad=True,factor=2)
    img = ut.normalize_image(img)
    name= sub_path_2 + '_' + str(i)
    ut.save_img_using_pil_lib(img,name,main_path+sub_path_2+'/')
    
#saving lr cropped and padded by fac 4
x,y,z = data_hr.shape
for i in range(x):
    img = ut.crop_pad_image_kspace(data_hr[i,:,:],pad=True,factor=4)
    img = ut.normalize_image(img)
    name= sub_path_4 + '_' + str(i)
    ut.save_img_using_pil_lib(img,name,main_path+sub_path_4+'/')


# saving lr cropped and padded by fac 8
x,y,z = data_hr.shape
for i in range(x):
    img = ut.crop_pad_image_kspace(data_hr[i,:,:],pad=True,factor=8)
    img = ut.normalize_image(img)
    name= sub_path_8 + '_'+str(i)
    ut.save_img_using_pil_lib(img,name,main_path+sub_path_8+'/')
    
    
# saving hr images
x,y,z = data_hr.shape
for i in range(x):
    name= hr_path+ '_'+str(i)
    img = ut.normalize_image(data_hr[i,:,:])
    ut.save_img_using_pil_lib(img,name,main_path + hr_path+'/')

# %% [markdown]
# ## F2 145

# %%
datapath_hr= '../OneDrive_1_11-10-2021/AD_P522R_F2_145/MRI_25um/mag_sos_wn.nii'
data_hr = ut.load_data_nii(datapath_hr)

main_path= '../images/25um/x_axis/f2_145/'
sub_path_2='hr_f2_145_2'
sub_path_4 ='hr_f2_145_4'
sub_path_8 ='hr_f2_145_8'
hr_path ='hr_f2_145'

# saving lr cropped and padded by fac 2
x,y,z = data_hr.shape
for i in range(x):
    img = ut.crop_pad_image_kspace(data_hr[i,:,:],pad=True,factor=2)
    img = ut.normalize_image(img)
    name= sub_path_2 + '_' + str(i)
    ut.save_img_using_pil_lib(img,name,main_path+sub_path_2+'/')
    
    
# saving lr cropped and padded by fac 4
x,y,z = data_hr.shape
for i in range(x):
    img = ut.crop_pad_image_kspace(data_hr[i,:,:],pad=True,factor=4)
    img = ut.normalize_image(img)
    name= sub_path_4 + '_' + str(i)
    ut.save_img_using_pil_lib(img,name,main_path+sub_path_4+'/')


# saving lr cropped and padded by fac 8
x,y,z = data_hr.shape
for i in range(x):
    img = ut.crop_pad_image_kspace(data_hr[i,:,:],pad=True,factor=8)
    img = ut.normalize_image(img)
    name= sub_path_8 + '_'+str(i)
    ut.save_img_using_pil_lib(img,name,main_path+sub_path_8+'/')
    
    
# saving hr images
x,y,z = data_hr.shape
for i in range(x):
    name= hr_path+ '_'+str(i)
    img = ut.normalize_image(data_hr[i,:,:])
    ut.save_img_using_pil_lib(img,name,main_path + hr_path+'/')

# %% [markdown]
# ## F4 149

# %%
datapath_hr= '../OneDrive_1_11-10-2021/AD_P522R_F4_149/MRI_25um/mag_sos_wn.nii'
data_hr = ut.load_data_nii(datapath_hr)

main_path= '../images/25um/x_axis/f4_149/'
sub_path_2='hr_f4_149_2'
sub_path_4='hr_f4_149_4'
sub_path_8 ='hr_f4_149_8'
hr_path ='hr_f4_149'

# saving lr cropped  and padded by fac 2
x,y,z = data_hr.shape
for i in range(x):
    img = ut.crop_pad_image_kspace(data_hr[i,:,:],pad=True,factor=2)
    img = ut.normalize_image(img)
    name= sub_path_2 + '_' + str(i)
    ut.save_img_using_pil_lib(img,name,main_path+sub_path_2+'/')
    
# saving lr cropped  and padded by fac 4
x,y,z = data_hr.shape
for i in range(x):
    img = ut.crop_pad_image_kspace(data_hr[i,:,:],pad=True,factor=4)
    img = ut.normalize_image(img)
    name= sub_path_4 + '_' + str(i)
    ut.save_img_using_pil_lib(img,name,main_path+sub_path_4+'/')


# # saving lr cropped and padded by fac 8
x,y,z = data_hr.shape
for i in range(x):
    img = ut.crop_pad_image_kspace(data_hr[i,:,:],pad=True,factor=8)
    img = ut.normalize_image(img)
    name= sub_path_8 + '_'+str(i)
    ut.save_img_using_pil_lib(img,name,main_path+sub_path_8+'/')
    
    
# # saving hr images
x,y,z = data_hr.shape
for i in range(x):
    name= hr_path+ '_'+str(i)
    img = ut.normalize_image(data_hr[i,:,:])
    ut.save_img_using_pil_lib(img,name,main_path + hr_path+'/')

# %% [markdown]
# ## F5 153

# %%
datapath_hr= '../OneDrive_1_11-10-2021/AD_P522R_F5_153/MRI_25um/mag_sos_wn.nii'
data_hr = ut.load_data_nii(datapath_hr)

main_path= '../images/25um/x_axis/f5_153/'
sub_path_2 ='hr_f5_153_2'
sub_path_4='hr_f5_153_4'
sub_path_8 ='hr_f5_153_8'
hr_path ='hr_f5_153'

# saving lr cropped and padded by fac 2
x,y,z = data_hr.shape
for i in range(x):
    img = ut.crop_pad_image_kspace(data_hr[i,:,:],pad=True,factor=2)
    img = ut.normalize_image(img)
    name= sub_path_2 + '_' + str(i)
    ut.save_img_using_pil_lib(img,name,main_path+sub_path_2+'/')

# saving lr cropped and padded by fac 2
x,y,z = data_hr.shape
for i in range(x):
    img = ut.crop_pad_image_kspace(data_hr[i,:,:],pad=True,factor=4)
    img = ut.normalize_image(img)
    name= sub_path_4 + '_' + str(i)
    ut.save_img_using_pil_lib(img,name,main_path+sub_path_4+'/')


# saving lr cropped and padded by fac 8
x,y,z = data_hr.shape
for i in range(x):
    img = ut.crop_pad_image_kspace(data_hr[i,:,:],pad=True,factor=8)
    img = ut.normalize_image(img)
    name= sub_path_8 + '_'+str(i)
    ut.save_img_using_pil_lib(img,name,main_path+sub_path_8+'/')
    
    
# saving hr images
x,y,z = data_hr.shape
for i in range(x):
    name= hr_path+ '_'+str(i)
    img = ut.normalize_image(data_hr[i,:,:])
    ut.save_img_using_pil_lib(img,name,main_path + hr_path+'/')
